# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.distance import pdist

import dionysus as d

from biomarker.data_collection import *
# Out:
# data_collection

# %%
EXCLUDE_KEYS = [206, 205, 184, 183, 82, 81, 45]
excel = parse_master_file(exclude_keys=EXCLUDE_KEYS).reset_index().drop(['index'], axis=1)
L = get_filename_list(excel['Associated data'])
# Out:
# [3, 9]

# %%
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
z =

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.scatter(Xc, Yc, Zc)
# ax.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False,
#     right='off', 
#     left='off', 
#     labelleft='off',
#     labelright='off') #
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Z')

# %%
n = 50

theta = np.linspace(0, 2.*np.pi, n)
phi = np.linspace(0, 2.*np.pi, n)
theta, phi = np.meshgrid(theta, phi)
c, a = 10, 1
x = (c + a*np.cos(theta)) * np.cos(phi)
y = (c + a*np.cos(theta)) * np.sin(phi)
z = a * np.sin(theta)

for s in [20, 200, 2000, 3000, 4000, 5000, 7000, 10000]:
    print(s)
    fig = plt.figure()
    ax1 = fig.add_subplot(111, projection='3d')
    ax1.scatter(x, y, z, color='black', s=10, alpha=1)
#     ax1.scatter(x, y, z, color='b', s=s, alpha=0.1, edgecolors='none')
    ax1.view_init(36, 26)
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax1.set_zticks([])
    plt.show()
# Out:
# 20
# <img src="data:image/png;base64,..." width="640">
# 200
# <img src="data:image/png;base64,..." width="640">
# 2000
# <img src="data:image/png;base64,..." width="640">
# 3000
# <img src="data:image/png;base64,..." width="640">
# 4000
# <img src="data:image/png;base64,..." width="640">
# 5000
# <img src="data:image/png;base64,..." width="640">
# 7000
# <img src="data:image/png;base64,..." width="640">
# 10000
# <img src="data:image/png;base64,..." width="640">
